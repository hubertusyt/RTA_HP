# %%
# Task 1.1 - Python version
import sys
print(f"Python: {sys.version}")
# Out:
# Python: 3.11.10 | packaged by conda-forge | (main, Oct 16 2024, 01:19:04) [GCC 13.3.0]

# %%
# Task 1.3 - Verify packages
import pandas as pd
import numpy as np
import sklearn

print(f"pandas:  {pd.__version__}")
print(f"numpy:   {np.__version__}")
print(f"sklearn: {sklearn.__version__}")
print("\nAll good! Your Python environment is ready.")
# Out:
# pandas:  2.2.3
# numpy:   2.0.2
# sklearn: 1.5.2
#
# All good! Your Python environment is ready.

# %%
# Task 4.3 - Course environment check
print(f"Python: {sys.version}")
print(f"Running inside: {sys.prefix}")
print("Course environment is ready!")
# Out:
# Python: 3.11.10 | packaged by conda-forge | (main, Oct 16 2024, 01:19:04) [GCC 13.3.0]
# Running inside: /opt/conda
# Course environment is ready!
